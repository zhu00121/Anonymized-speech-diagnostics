# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
toy = librosa.load('/mnt/d/projects/COVID-datasets/DiCOVA2/audio/speech/DAOJYZLP_ss.flac',sr=16000)

# %%
fake = np.ones((16000,))*1e-15

# %%
import scipy.io.wavfile
scipy.io.wavfile.write('/mnt/d/projects/COVID-datasets/DiCOVA2/audio/speech/MCPGSBRU_mcadams.wav', 16000, np.float32(fake))

# %%
np.isfinite(toy[0]).all()
# Out:
# True

# %%
plt.plot(toy[0])
